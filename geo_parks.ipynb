# %%
from shapely.geometry import Point
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
import folium
from folium.plugins import MarkerCluster
from folium.plugins import FastMarkerCluster

# %%
parks = gpd.read_file('./data/USA Parks.geojson')

# %%
parks.head()
# Out:
#    FID                 NAME FCC  SQMI    FEATTYPE   Shape__Area  \
# 0  501      North Pole Park      0.01  Local park  2.117713e+05
# 1  502  Growden Picnic Area      0.01  Local park  2.052648e+05
# 2  503     Slaterville Park      0.00  Local park  3.457462e+04
# 3  504           Kiana Park      0.02  Local park  2.186409e+05
# 4  505     South Davis Park      0.20  Local park  2.837634e+06
#
#    Shape__Length                                           geometry
# 0    1935.930425  POLYGON ((-147.34223 64.74934, -147.34223 64.7...
# 1    1960.116532  POLYGON ((-147.75565 64.83899, -147.75568 64.8...
# 2     850.534900  POLYGON ((-147.71552 64.84745, -147.71557 64.8...
# 3    1859.114661  POLYGON ((-147.78730 64.83303, -147.79135 64.8...
# 4    8047.091935  POLYGON ((-147.74491 64.82434, -147.74492 64.8...

# %%
parks.FEATTYPE.unique()
# Out:
# array(['Local park', 'State park or forest', 'Regional park',
#        'National park or forest', 'County park'], dtype=object)

# %%
natlparks = parks.loc[parks['FEATTYPE'] == 'National park or forest']

# %%
natlparks
# Out:
#          FID                                          NAME FCC      SQMI  \
# 20       521          Yukon Flats National Wildlife Refuge      17368.83
# 21       522                       Tongass National Forest       1615.94
# 29       530                Sitka National Historical Park          0.23
# 31       532  Pleasant Lemusurier Inian Islands Wilderness         80.80
# 33       534        Glacier Bay National Park and Preserve       4128.69
# ...      ...                                           ...  ..       ...
# 58014  57987                                    Agat Beach          1.20
# 58018  57991                                    Mt. Alifan          0.11
# 58022  57995                        Mt. Chachao/ Mt. Tenjo          0.16
# 58026  57999                                    Asan Beach          0.90
# 58027  58000                                     Piti Guns          0.04
#
#                       FEATTYPE   Shape__Area  Shape__Length  \
# 20     National park or forest  2.820591e+11   3.847098e+06
# 21     National park or forest  1.629266e+10   1.403539e+06
# 29     National park or forest  2.031801e+06   8.611606e+03
# 31     National park or forest  7.263761e+08   6.938059e+05
# 33     National park or forest  3.980844e+10   4.105808e+06
# ...                        ...           ...            ...
# 58014  National park or forest  3.309005e+06   9.414164e+03
# 58018  National park or forest  3.048508e+05   2.694704e+03
# 58022  National park or forest  4.507389e+05   5.641698e+03
# 58026  National park or forest  2.471760e+06   7.510353e+03
# 58027  National park or forest  1.053173e+05   1.497642e+03
#
#                                                 geometry
# 20     POLYGON ((-146.41460 65.71830, -146.40641 65.7...
# 21     MULTIPOLYGON (((-138.19554 59.17779, -138.1955...
# 29     POLYGON ((-135.30739 57.04233, -135.30736 57.0...
# 31     MULTIPOLYGON (((-134.66664 56.16763, -134.6664...
# 33     MULTIPOLYGON (((-136.65046 58.21120, -136.6495...
# ...                                                  ...
# 58014  POLYGON ((144.65198 13.37644, 144.65194 13.376...
# 58018  POLYGON ((144.66879 13.38213, 144.66882 13.385...
# 58022  POLYGON ((144.69957 13.42191, 144.69975 13.422...
# 58026  MULTIPOLYGON (((144.66395 13.39024, 144.66401 ...
# 58027  POLYGON ((144.69775 13.45829, 144.69776 13.458...
#
# [858 rows x 8 columns]

# %%
#natlparks.to_file('./data/natlparks.geojson')
